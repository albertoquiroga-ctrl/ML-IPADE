# %% [markdown]
# # Bobs Case
#
# 1. Introduction
# 2. Data Wrangling
# 3. Linear Regression

# %% [markdown]
# ## Prompt for Data Wrangling
#
# ### Role
# You are a business analyst.
#
# ### Task
# Please read and analyse the attached csv files
#
# ### Context
# Using and anonymous super market data set
#
# ### Outcome
